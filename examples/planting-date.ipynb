# %%
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
pd.read_csv("https://zenodo.org/records/7790257/files/maize_countyStats_doyPercentPlanted_2000-2020_DeinesEtAl_vRSE.csv?download=1")
# Out:
#        GEOID        county state  county_code  state_code state_name   crop  \
# 0      17001  Adams County    IL            1          17   Illinois  Maize
# 1      17001  Adams County    IL            1          17   Illinois  Maize
# 2      17001  Adams County    IL            1          17   Illinois  Maize
# 3      17001  Adams County    IL            1          17   Illinois  Maize
# 4      17001  Adams County    IL            1          17   Illinois  Maize
# ...      ...           ...   ...          ...         ...        ...    ...
# 21826  55141   Wood County    WI          141          55  Wisconsin  Maize
# 21827  55141   Wood County    WI          141          55  Wisconsin  Maize
# 21828  55141   Wood County    WI          141          55  Wisconsin  Maize
# 21829  55141   Wood County    WI          141          55  Wisconsin  Maize
# 21830  55141   Wood County    WI          141          55  Wisconsin  Maize
#
#        Year  doy_10  doy_25  doy_50  doy_75  doy_90
# ...
